# %%
import pandas as pd

# %%
#loading the dataset

# %%
df=pd.read_csv("D:/sem 6/NM/House Price India.csv")

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
#performing descriptive analysis and descriptive statistics

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
#since no null values we need not replace any values using sum or mean rule or even drop them

# %%
#drop irrelevant columns like date and id

# %%
df=df.drop(['id','Date'],axis=1)

# %%
df
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
#checking outliers

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
sns.boxplot(df['number of bedrooms'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number of bedrooms'>

# %%
#since it is normal distribution we are using zscore for outliers

# %%
from scipy import stats

# %%
zs=np.abs(stats.zscore(df['number of bedrooms']))
zs
# Out:
# 0        1.726515
# 1        0.661197
# 2        1.726515
# 3        0.661197
# 4        0.404121
#            ...
# 14615    1.469439
# 14616    0.404121
# 14617    1.469439
# 14618    0.661197
# 14619    0.404121
# Name: number of bedrooms, Length: 14620, dtype: float64

# %%
Threshold=3
print(np.where(zs>3),len(np.where(zs>3)[0]))
# Out:
# (array([   76,   243,   268,   275,   624,   785,  1512,  1519,  1553,
#         1706,  2814,  3109,  3114,  3322,  3532,  3600,  4207,  4486,
#         4658,  4680,  6591,  6596,  6730,  6982,  6998,  7003,  7454,
#         8559,  8650,  9282,  9629,  9810,  9955, 10168, 10177, 10676,
#        10748, 10916, 10944, 11247, 11441, 11547, 11877, 12273, 13048,
#        13444, 13825, 14220, 14481], dtype=int64),) 49

# %%
print(np.where(zs<-3))
# Out:
# (array([], dtype=int64),)

# %%
df1=df[(zs<3)]

# %%
#after removing outliers

# %%
sns.boxplot(df1['number of bedrooms'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number of bedrooms'>

# %%
#similarly do check for outliers in all columns and remove them

# %%
sns.boxplot(df1['number of bathrooms'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number of bathrooms'>

# %%
zs=np.abs(stats.zscore(df1['number of bathrooms']))

# %%
len(np.where(zs>3)[0])
# Out:
# 124

# %%
len(np.where(zs<-3))
# Out:
# 1

# %%
df1=df1[(zs<3)]

# %%
sns.boxplot(df1['number of bathrooms'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='number of bathrooms'>

# %%
#after removing outliers
df1
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
#drop insignificant columns

# %%
df1.drop(['Renovation Year'],axis=1)
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  \
# 0                       5                 2.50         3650      9050
# 1                       4                 2.50         2920      4000
# 2                       5                 2.75         2910      9480
# 3                       4                 2.50         3310     42998
# 4                       3                 2.00         2710      4500
# ...                   ...                  ...          ...       ...
# 14615                   2                 1.50         1556     20000
# 14616                   3                 2.00         1680      7000
# 14617                   2                 1.00         1070      6120
# 14618                   4                 1.00         1030      6621
# 14619                   3                 1.00          900      4770
#
#        number of floors  waterfront present  number of views  \
# 0                   2.0                   0                4
# ...

# %%
df1['Number of schools nearby'].std()
# Out:
# 0.8167557786931794

# %%
#UNIVARIATE ANALYSIS

# %%
sns.countplot(x='number of bedrooms',data=df1,)
plt.show()

# %%
df1['Number of schools nearby'].value_counts()
# Out:
# 3    4909
# 2    4808
# 1    4730
# Name: Number of schools nearby, dtype: int64

# %%
df1['Number of schools nearby'].mean()
# Out:
# 2.012390115594933

# %%
df1['Number of schools nearby'].median()
# Out:
# 2.0

# %%
df1['Number of schools nearby'].mode()
# Out:
# 0    3
# Name: Number of schools nearby, dtype: int64

# %%
sns.distplot(df1['number of bathrooms'],hist=True,kde=True)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df1['number of bathrooms'].kurt()
# Out:
# -0.371253641581327

# %%
df1['Built Year'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
plt.pie(df['grade of the house'].value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x1337b570e20>,
# ...
#  [Text(0.3030748468971545, 1.057424057404723, ''),
#   Text(-1.0403949018887162, -0.35718125388095134, ''),
#   Text(0.04584291876484192, -1.0990443243104986, ''),
#   Text(0.7244952561785445, -0.8277116791339757, ''),
#   Text(1.0154969646313872, -0.4228071839792215, ''),
#   Text(1.085669624177062, -0.17697871945303728, ''),
#   Text(1.0974328475701316, -0.07510755670445161, ''),
#   Text(1.0996982848333383, -0.025762032812152582, ''),
#   Text(1.0999652337410808, -0.00874554520483374, ''),
#   Text(1.0999974606228988, -0.0023636038531350346, '')])

# %%
#before removing outliers
sns.boxplot(x='number of bedrooms', data=df)
# Out:
# <AxesSubplot:xlabel='number of bedrooms'>

# %%
#after removing outliers

# %%
sns.boxplot(x='number of bedrooms', data=df1)
# Out:
# <AxesSubplot:xlabel='number of bedrooms'>

# %%
#BIVARIATE ANALYSIS

# %%
def graph(y):
    sns.boxplot(x="grade of the house", y=y, data=df1)
plt.figure(figsize=(10,10))
plt.subplot(221)
graph('condition of the house')
plt.subplot(222)
graph('number of views')
plt.subplot(223)
graph('Built Year')
plt.subplot(224)
graph('living area')
plt.show()

# %%
df1[['grade of the house','Price']].corr()
# Out:
#                     grade of the house     Price
# grade of the house            1.000000  0.674913
# Price                         0.674913  1.000000

# %%
sns.barplot(data=df1,x='number of bathrooms',y='Price')
# Out:
# <AxesSubplot:xlabel='number of bathrooms', ylabel='Price'>

# %%
sns.barplot(data=df1,x='number of bedrooms',y='Price')
# Out:
# <AxesSubplot:xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.scatterplot(x='Lattitude', y='Longitude', hue='grade of the house', data=df1, )
plt.legend(bbox_to_anchor=(1, 1), loc=2)
plt.show()

# %%
#MULTIVARIATE ANALYSIS

# %%
df1.describe()
# Out:
#        number of bedrooms  number of bathrooms   living area      lot area  \
# count        14447.000000         14447.000000  14447.000000  1.444700e+04
# mean             3.350869             2.100540   2066.356337  1.490809e+04
# std              0.862499             0.718173    865.042798  3.760185e+04
# min              1.000000             0.500000    370.000000  5.200000e+02
# 25%              3.000000             1.750000   1430.000000  5.001000e+03
# 50%              3.000000             2.250000   1920.000000  7.582000e+03
# 75%              4.000000             2.500000   2541.000000  1.070900e+04
# max              6.000000             4.250000   7620.000000  1.074218e+06
#
#        number of floors  waterfront present  number of views  \
# count      14447.000000        14447.000000     14447.000000
# mean           1.497716            0.007060         0.225237
# std            0.539421            0.083731         0.752451
# ...

# %%
df1.head(10)
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
# 3                   4                 2.50         3310     42998
# 4                   3                 2.00         2710      4500
# 5                   3                 2.50         2600      4750
# 6                   5                 3.25         3660     11995
# 7                   3                 1.75         2240     10578
# 8                   3                 2.50         2390      6550
# 9                   4                 2.25         2200     11250
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(10,10))
axes[0,0].set_title("House price")
axes[0,0].hist(df1['Price'], bins=20)
axes[0,1].set_title("Based on schools nearby")
axes[0,1].hist(df1['Number of schools nearby'], bins=20);
axes[1,0].set_title("Based on built year")
axes[1,0].hist(df1['Built Year'], bins=20)
axes[1,1].set_title("Based on number of Bedrooms")
axes[1,1].hist(df1['number of bedrooms'], bins=10);

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df1.corr(),linewidths=0.5,annot=True,cmap='Blues')
plt.show()

# %%
sns.pairplot(df1.drop(['waterfront present','Lattitude','Longitude','number of views','lot area','lot_area_renov'], axis = 1), hue='condition of the house', height=2)

# %%
plt.figure(figsize=(19,7))
sns.heatmap(df1.corr(method='pearson').drop( ['waterfront present','Lattitude','Longitude','number of views','lot area','lot_area_renov'], axis=1).drop(['waterfront present','Lattitude','Longitude','number of views','lot area','lot_area_renov'], axis=0),
annot = True,cmap='Blues');
plt.show()
